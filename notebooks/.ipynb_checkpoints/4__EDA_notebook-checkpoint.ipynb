# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Libraries and Data

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns

plt.style.use('fivethirtyeight')

# %matplotlib inline

pd.set_option('display.max_columns', 500)

# %%
# import senator data
sens = pd.read_csv('/')
sens.drop('Unnamed: 0', inplace=True, axis = 1)
sens.sort_values('race_id', inplace=True)
print(sens.shape)
sens.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-834e1ec9770a> in <module>()
#       1 # import senator data
# ----> 2 sens = pd.read_csv('./data/sens_final.csv')
#       3 sens.drop('Unnamed: 0', inplace=True, axis = 1)
#       4 sens.sort_values('race_id', inplace=True)
#       5 print(sens.shape)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./data/sens_final.csv' does not exist

# %%
# import govs data
govs = pd.read_csv('./data/sens_final.csv')
govs.drop('Unnamed: 0', inplace=True, axis = 1)
govs.sort_values('race_id', inplace=True)
print(govs.shape)
govs.head(10)
# Out:
# (793, 43)
#          race_id  office loc_date_id   state abbrev  year  GOP_win  \
# 53   AK_sen_1978  AK_sen     AK_1978  Alaska     AK  1978        1
# 98   AK_sen_1984  AK_sen     AK_1984  Alaska     AK  1984        1
# 99   AK_sen_1984  AK_sen     AK_1984  Alaska     AK  1984        1
# 383  AK_sen_1986  AK_sen     AK_1986  Alaska     AK  1986        1
# 384  AK_sen_1986  AK_sen     AK_1986  Alaska     AK  1986        1
# 385  AK_sen_1986  AK_sen     AK_1986  Alaska     AK  1986        1
# 153  AK_sen_1990  AK_sen     AK_1990  Alaska     AK  1990        1
# 193  AK_sen_1992  AK_sen     AK_1992  Alaska     AK  1992        1
# 15   AK_sen_1996  AK_sen     AK_1996  Alaska     AK  1996        1
# 468  AK_sen_1998  AK_sen     AK_1998  Alaska     AK  1998        1
#
#               winner             rival  pred_GOP  pred_DEM  unopposed  \
# 53       Ted Stevens   Donald W  Hobbs         1         0          0
# 98       Ted Stevens  John E  Havelock         1         0          0
# 99       Ted Stevens  John E  Havelock         1         0          0
# 383  Frank Murkowski        Glenn Olds         1         0          0
# 384  Frank Murkowski        Glenn Olds         1         0          0
# 385  Frank Murkowski        Glenn Olds         1         0          0
# 153      Ted Stevens   Michael Beasley         1         0          0
# 193  Frank Murkowski        Tony Smith         1         0          0
# 15       Ted Stevens    Jeff Whittaker         1         0          0
# 468  Frank Murkowski      Joe Sonneman         1         0          0
#
#      inc_GOP_running  inc_DEM_running  prez_GOP  approval_effects_GOP  \
# 53                 1                0       0.0              0.000000
# 98                 1                0       1.0             22.000000
# 99                 1                0       1.0             22.000000
# 383                1                0       1.0             36.000000
# 384                1                0       1.0             36.000000
# 385                1                0       1.0             36.000000
# 153                1                0       1.0             27.666667
# 193                1                0       1.0            -24.250000
# 15                 1                0       0.0              0.000000
# 468                1                0       0.0              0.000000
#
#      approval_effects_DEM  nat_UR_effects_GOP  nat_UR_effects_DEM  \
# 53              13.000000                 0.0                 5.8
# 98               0.000000                 7.4                 0.0
# 99               0.000000                 7.4                 0.0
# 383              0.000000                 7.0                 0.0
# 384              0.000000                 7.0                 0.0
# 385              0.000000                 7.0                 0.0
# 153              0.000000                 5.9                 0.0
# 193              0.000000                 7.3                 0.0
# 15              21.000000                 0.0                 5.2
# 468             32.666667                 0.0                 4.5
#
#      state_UR_effects_GOP  state_UR_effects_DEM  total_male  total_female  \
# 53                    0.0                  10.2      203084        178473
# 98                    9.5                   0.0      243771        217356
# 99                    9.5                   0.0      243771        217356
# 383                  11.0                   0.0      259137        231630
# 384                  11.0                   0.0      259137        231630
# 385                  11.0                   0.0      259137        231630
# 153                   7.3                   0.0      289867        260176
# 193                   8.6                   0.0      296716        268705
# 15                    0.0                   7.5      310414        285762
# 468                   0.0                   6.4      317263        294291
#
#      age_under18  age_18to29  age_30to59  age_60over  race_white_nh  \
# 53        128568      101180      133656       18154         288403
# 98        147385      108726      179125       25892         340553
# 99        147385      108726      179125       25892         340553
# 383       155704      108880      197165       29017         359597
# 384       155704      108880      197165       29017         359597
# 385       155704      108880      197165       29017         359597
# 153       172344      109188      233245       35266         397689
# 193       176019      107406      243178       38818         399887
# 15        183368      103843      263044       45922         404285
# 468       187042      102061      272977       49474         406484
#
#      race_black  race_natamer  race_asian  race_hispanic  percent_male  \
# 53        12781         54741       14337           8525      0.532251
# 98        17229         72893       15549          12825      0.528642
# 99        17229         72893       15549          12825      0.528642
# 383       18970         77162       19167          14485      0.528025
# 384       18970         77162       19167          14485      0.528025
# 385       18970         77162       19167          14485      0.528025
# 153       22451         85698       26402          17803      0.526990
# 193       22318         88167       28806          19413      0.524770
# 15        22053         93105       33614          22632      0.520675
# 468       21920         95574       36018          24242      0.518782
#
#      percent_female  percent_under18  percent_age_18to29  percent_age_30to59  \
# 53         0.467749         0.336956            0.265177            0.350291
# 98         0.471358         0.319619            0.235783            0.388450
# 99         0.471358         0.319619            0.235783            0.388450
# 383        0.471975         0.317267            0.221857            0.401749
# 384        0.471975         0.317267            0.221857            0.401749
# 385        0.471975         0.317267            0.221857            0.401749
# 153        0.473010         0.313328            0.198508            0.424049
# 193        0.475230         0.311306            0.189958            0.430083
# 15         0.479325         0.307574            0.174182            0.441219
# 468        0.481218         0.305847            0.166888            0.446366
#
#      percent_age_60over  percent_race_white  percent_race_black  \
# 53             0.047579            0.755858            0.033497
# 98             0.056149            0.738523            0.037363
# 99             0.056149            0.738523            0.037363
# 383            0.059126            0.732724            0.038654
# 384            0.059126            0.732724            0.038654
# 385            0.059126            0.732724            0.038654
# 153            0.064115            0.723014            0.040817
# 193            0.068653            0.707238            0.039471
# 15             0.077028            0.678130            0.036991
# 468            0.080899            0.664674            0.035843
#
#      percent_race_natamer  percent_race_asian  percent_race_hispanic
# 53               0.143467            0.037575               0.022343
# 98               0.158076            0.033720               0.027812
# 99               0.158076            0.033720               0.027812
# 383              0.157227            0.039055               0.029515
# 384              0.157227            0.039055               0.029515
# 385              0.157227            0.039055               0.029515
# 153              0.155802            0.048000               0.032367
# 193              0.155932            0.050946               0.034334
# 15               0.156170            0.056383               0.037962
# 468              0.156281            0.058896               0.039640

# %% [markdown]
# ## Lists and Functions to Use

# %%
#lists
state_codes = govs.abbrev.unique()
state_names = govs.state.unique()
years = list(range(1976, 2018))

# id_cols = ['race_id', 'office' 'loc_date_id', 'state', 'abbrev', 'year', 'winner', 'rival']
id_cols = ['race_id', 'office', 'loc_date_id', 'state', 'abbrev', 'winner', 'rival']

# %%
print(state_codes, len(state_codes))
print(state_names, len(state_names))
print(years, len(years))
# Out:
# ['AK' 'AL' 'AR' 'AZ' 'CA' 'CO' 'CT' 'DE' 'FL' 'GA' 'HI' 'IA' 'ID' 'IL'
#  'IN' 'KS' 'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC' 'ND'
#  'NE' 'NH' 'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'RI' 'SC' 'SD' 'TN'
#  'TX' 'UT' 'VA' 'VT' 'WA' 'WI' 'WV' 'WY'] 50
# ['Alaska' 'Alabama' 'Arkansas' 'Arizona' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Iowa' 'Idaho'
#  'Illinois' 'Indiana' 'Kansas' 'Kentucky' 'Louisiana' 'Massachusetts'
#  'Maryland' 'Maine' 'Michigan' 'Minnesota' 'Missouri' 'Mississippi'
#  'Montana' 'North_Carolina' 'North_Dakota' 'Nebraska' 'New_Hampshire'
#  'New_Jersey' 'New_Mexico' 'Nevada' 'New_York' 'Ohio' 'Oklahoma' 'Oregon'
#  'Pennsylvania' 'Rhode_Island' 'South_Carolina' 'South_Dakota' 'Tennessee'
#  'Texas' 'Utah' 'Virginia' 'Vermont' 'Washington' 'Wisconsin'
#  'West_Virginia' 'Wyoming'] 50
# [1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017] 42

# %%
#functions

def state_filter(code, df=sens):
    df_state = df[df['abbrev'] == code]
    return df_state

# %% [markdown]
# ## Examine Data

# %% [markdown]
# ### Data Types

# %%
print("Governors Data Types:\n", govs.dtypes, '\n\n')
print("Senators Data Types:\n", sens.dtypes)
# Out:
# Governors Data Types:
#  race_id                   object
# office                    object
# loc_date_id               object
# state                     object
# abbrev                    object
# year                       int64
# GOP_win                    int64
# winner                    object
# rival                     object
# pred_GOP                   int64
# pred_DEM                   int64
# unopposed                  int64
# inc_GOP_running            int64
# inc_DEM_running            int64
# prez_GOP                 float64
# approval_effects_GOP     float64
# approval_effects_DEM     float64
# nat_UR_effects_GOP       float64
# nat_UR_effects_DEM       float64
# state_UR_effects_GOP     float64
# state_UR_effects_DEM     float64
# total_male                 int64
# total_female               int64
# age_under18                int64
# age_18to29                 int64
# age_30to59                 int64
# age_60over                 int64
# race_white_nh              int64
# race_black                 int64
# race_natamer               int64
# race_asian                 int64
# race_hispanic              int64
# percent_male             float64
# percent_female           float64
# percent_under18          float64
# percent_age_18to29       float64
# percent_age_30to59       float64
# percent_age_60over       float64
# percent_race_white       float64
# percent_race_black       float64
# percent_race_natamer     float64
# percent_race_asian       float64
# percent_race_hispanic    float64
# dtype: object
#
#
# Senators Data Types:
#  race_id                   object
# office                    object
# loc_date_id               object
# state                     object
# abbrev                    object
# year                       int64
# GOP_win                    int64
# winner                    object
# rival                     object
# pred_GOP                   int64
# pred_DEM                   int64
# unopposed                  int64
# inc_GOP_running            int64
# inc_DEM_running            int64
# prez_GOP                 float64
# approval_effects_GOP     float64
# approval_effects_DEM     float64
# nat_UR_effects_GOP       float64
# nat_UR_effects_DEM       float64
# state_UR_effects_GOP     float64
# state_UR_effects_DEM     float64
# total_male                 int64
# total_female               int64
# age_under18                int64
# age_18to29                 int64
# age_30to59                 int64
# age_60over                 int64
# race_white_nh              int64
# race_black                 int64
# race_natamer               int64
# race_asian                 int64
# race_hispanic              int64
# percent_male             float64
# percent_female           float64
# percent_under18          float64
# percent_age_18to29       float64
# percent_age_30to59       float64
# percent_age_60over       float64
# percent_race_white       float64
# percent_race_black       float64
# percent_race_natamer     float64
# percent_race_asian       float64
# percent_race_hispanic    float64
# dtype: object

# %% [markdown]
# ### Correlation

# %%
sen_vals = sens.drop(id_cols, axis=1)
gov_vals = govs.drop(id_cols, axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,20))
plt.title("Variable Heatmap")
sns.heatmap(sen_vals.corr(), cmap = 'coolwarm', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ad86e2c78f4> in <module>()
# ----> 1 fig, ax = plt.subplots(figsize=(20,20))
#       2 plt.title("Variable Heatmap")
#       3 sns.heatmap(sen_vals.corr(), cmap = 'coolwarm', ax=ax)
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(gov_vals.corr(), cmap = 'coolwarm', ax=ax)

# %% [markdown]
# ### Variable Distribution

# %%
for col in list(sen_vals.columns):
    print(col, '\n')
    print(sen_vals[col].describe(), '\n')
# Out:
# year
#
# count     793.000000
# mean     1996.007566
# std        11.093949
# min      1978.000000
# 25%      1986.000000
# 50%      1996.000000
# 75%      2004.000000
# max      2016.000000
# Name: year, dtype: float64
#
# GOP_win
#
# count    793.000000
# mean       0.496847
# std        0.500306
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: GOP_win, dtype: float64
#
# pred_GOP
#
# count    793.000000
# mean       0.518285
# std        0.499981
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: pred_GOP, dtype: float64
#
# pred_DEM
#
# count    793.000000
# mean       0.465322
# std        0.499111
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: pred_DEM, dtype: float64
#
# unopposed
#
# count    793.000000
# mean       0.005044
# std        0.070887
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: unopposed, dtype: float64
#
# inc_GOP_running
#
# count    793.000000
# mean       0.409836
# std        0.492114
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: inc_GOP_running, dtype: float64
#
# inc_DEM_running
#
# count    793.000000
# mean       0.360656
# std        0.480494
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: inc_DEM_running, dtype: float64
#
# prez_GOP
#
# count    793.000000
# mean       0.602774
# std        0.489632
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: prez_GOP, dtype: float64
#
# approval_effects_GOP
#
# count    793.000000
# mean      10.171501
# std       19.116362
# min      -24.250000
# 25%        0.000000
# 50%        0.000000
# 75%       36.000000
# max       36.666667
# Name: approval_effects_GOP, dtype: float64
#
# approval_effects_DEM
#
# count    793.000000
# mean       3.480706
# std        9.590414
# min      -11.800000
# 25%        0.000000
# 50%        0.000000
# 75%        5.222222
# max       32.666667
# Name: approval_effects_DEM, dtype: float64
#
# nat_UR_effects_GOP
#
# count    793.000000
# mean       4.159395
# std        3.611327
# min        0.000000
# 25%        0.000000
# 50%        5.700000
# 75%        7.000000
# max       10.400000
# Name: nat_UR_effects_GOP, dtype: float64
#
# nat_UR_effects_DEM
#
# count    793.000000
# mean       2.357377
# std        3.085421
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        5.200000
# max        9.400000
# Name: nat_UR_effects_DEM, dtype: float64
#
# state_UR_effects_GOP
#
# count    793.000000
# mean       3.964817
# std        3.716454
# min        0.000000
# 25%        0.000000
# 50%        4.500000
# 75%        6.500000
# max       16.800000
# Name: state_UR_effects_GOP, dtype: float64
#
# state_UR_effects_DEM
#
# count    793.000000
# mean       2.217528
# std        3.006455
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        4.700000
# max       13.700000
# Name: state_UR_effects_DEM, dtype: float64
#
# total_male
#
# count    7.930000e+02
# mean     2.583100e+06
# std      2.845250e+06
# min      2.030840e+05
# 25%      7.452530e+05
# 50%      1.776331e+06
# 75%      2.998947e+06
# max      1.950359e+07
# Name: total_male, dtype: float64
#
# total_female
#
# count    7.930000e+02
# mean     2.695049e+06
# std      2.935139e+06
# min      1.784730e+05
# 25%      7.460540e+05
# 50%      1.851171e+06
# 75%      3.176433e+06
# max      1.977975e+07
# Name: total_female, dtype: float64
#
# age_under18
#
# count    7.930000e+02
# mean     1.349951e+06
# std      1.476598e+06
# min      1.182590e+05
# 25%      3.993980e+05
# 50%      9.332620e+05
# 75%      1.550710e+06
# max      9.322167e+06
# Name: age_under18, dtype: float64
#
# age_18to29
#
# count    7.930000e+02
# mean     9.628346e+05
# std      1.075788e+06
# min      7.465400e+04
# 25%      2.760300e+05
# 50%      6.834100e+05
# 75%      1.163939e+06
# max      7.122033e+06
# Name: age_18to29, dtype: float64
#
# age_30to59
#
# count    7.930000e+02
# mean     2.274762e+06
# std      2.634077e+06
# min      1.336560e+05
# 25%      6.078450e+05
# 50%      1.515603e+06
# 75%      2.777565e+06
# max      2.250893e+07
# Name: age_30to59, dtype: float64
#
# age_60over
#
# count    7.930000e+02
# mean     8.994770e+05
# std      9.711117e+05
# min      1.815400e+04
# 25%      2.506270e+05
# 50%      6.095810e+05
# 75%      1.058857e+06
# max      6.880438e+06
# Name: age_60over, dtype: float64
#
# race_white_nh
#
# count    7.930000e+02
# mean     3.444597e+06
# std      2.862835e+06
# min      2.064030e+05
# 25%      1.148309e+06
# 50%      2.658937e+06
# 75%      4.708856e+06
# max      1.350890e+07
# Name: race_white_nh, dtype: float64
#
# race_black
#
# count    7.930000e+02
# mean     6.526583e+05
# std      7.832140e+05
# min      1.341000e+03
# 25%      4.268800e+04
# 50%      2.535900e+05
# 75%      1.162994e+06
# max      3.398476e+06
# Name: race_black, dtype: float64
#
# race_natamer
#
# count       793.000000
# mean      45571.447667
# std       66105.962228
# min        1180.000000
# 25%       10608.000000
# 50%       21399.000000
# 75%       50100.000000
# max      380474.000000
# Name: race_natamer, dtype: float64
#
# race_asian
#
# count    7.930000e+02
# mean     4.155550e+05
# std      1.215351e+06
# min      1.770000e+03
# 25%      2.714800e+04
# 50%      9.709900e+04
# 75%      3.225950e+05
# max      1.241840e+07
# Name: race_asian, dtype: float64
#
# race_hispanic
#
# count    7.930000e+02
# mean     6.148705e+05
# std      1.696093e+06
# min      3.375000e+03
# 25%      3.381000e+04
# 50%      1.165320e+05
# 75%      3.904680e+05
# max      1.584202e+07
# Name: race_hispanic, dtype: float64
#
# percent_male
#
# count    793.000000
# mean       0.491052
# std        0.008666
# min        0.475879
# 25%        0.485043
# 50%        0.489757
# 75%        0.495817
# max        0.532251
# Name: percent_male, dtype: float64
#
# percent_female
#
# count    793.000000
# mean       0.508948
# std        0.008666
# min        0.467749
# 25%        0.504183
# 50%        0.510243
# 75%        0.514957
# max        0.524121
# Name: percent_female, dtype: float64
#
# percent_under18
#
# count    793.000000
# mean       0.260226
# std        0.026624
# min        0.185974
# 25%        0.243618
# 50%        0.257453
# 75%        0.273582
# max        0.368424
# Name: percent_under18, dtype: float64
#
# percent_age_18to29
#
# count    793.000000
# mean       0.183195
# std        0.022001
# min        0.137933
# 25%        0.166051
# 50%        0.177006
# 75%        0.201907
# max        0.265177
# Name: percent_age_18to29, dtype: float64
#
# percent_age_30to59
#
# count    793.000000
# mean       0.424155
# std        0.080247
# min        0.292309
# 25%        0.365338
# 50%        0.406340
# 75%        0.462088
# max        0.985188
# Name: percent_age_30to59, dtype: float64
#
# percent_age_60over
#
# count    793.000000
# mean       0.169586
# std        0.026888
# min        0.047579
# 25%        0.155410
# 50%        0.171392
# 75%        0.185288
# max        0.241378
# Name: percent_age_60over, dtype: float64
#
# percent_race_white
#
# count    793.000000
# mean       0.738928
# std        0.176800
# min        0.152715
# 25%        0.645317
# 50%        0.767891
# 75%        0.875891
# max        0.986166
# Name: percent_race_white, dtype: float64
#
# percent_race_black
#
# count    793.000000
# mean       0.099896
# std        0.095028
# min        0.002329
# 25%        0.021266
# 50%        0.070987
# 75%        0.153021
# max        0.372707
# Name: percent_race_black, dtype: float64
#
# percent_race_natamer
#
# count    793.000000
# mean       0.016533
# std        0.029405
# min        0.000999
# 25%        0.002705
# 50%        0.005043
# 75%        0.012397
# max        0.158076
# Name: percent_race_natamer, dtype: float64
#
# percent_race_asian
#
# count    793.000000
# mean       0.056115
# std        0.087706
# min        0.002475
# 25%        0.012326
# 50%        0.031135
# 75%        0.064122
# max        0.637340
# Name: percent_race_asian, dtype: float64
#
# percent_race_hispanic
#
# count    793.000000
# mean       0.070713
# std        0.085568
# min        0.004090
# 25%        0.016922
# 50%        0.038651
# 75%        0.088378
# max        0.477262
# Name: percent_race_hispanic, dtype: float64

# %% [markdown]
# ### Graphs Over Time

# %%
def scatter_time(col, df):
    fig, ax = plt.subplots(figsize=(8,8))
    plt.scatter(df['year'], df[col])
    plt.xlabel("year")
    plt.ylabel(col)

# %%
for col in list(sen_vals.columns):
    scatter_time(col, sen_vals)
# Out:
# C:\Users\Alexz\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
